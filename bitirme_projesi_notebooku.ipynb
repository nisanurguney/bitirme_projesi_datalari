# %% [markdown]
# <a href="https://colab.research.google.com/github/nisanurguney/bitirme_projesi_datalari/blob/main/bitirme_projesi_notebooku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bazı verilerde sayı türünde uyuşmazlıklar olduğu için python'da düzeltmeler yapılmıştır.

# %% [markdown]
# Hastane Yatak Sayılarının İllere Göre Dağılımı tablosunun düzeltilmesi

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b39d2a7f-11d0-4e57-9a39-d3bb545d56bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b39d2a7f-11d0-4e57-9a39-d3bb545d56bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("dosya1.csv", encoding="utf-8")

# %%
df.head()
# Out:
#   Province                          hospital_type  year  beds
# 0    Adana  Sağlık Bakanlığı - Ministry of Health  2020  4121
# 1    Adana  Sağlık Bakanlığı - Ministry of Health  2021  4176
# 2    Adana  Sağlık Bakanlığı - Ministry of Health  2022  4265
# 3    Adana  Sağlık Bakanlığı - Ministry of Health  2023  4510
# 4    Adana                Üniversite - University  2020  1747

# %%
df.columns = ["province", "hospital_type", "year", "beds"]

# %%
df["province"] = df["province"].astype(str)
df["hospital_type"] = df["hospital_type"].astype(str)

# %%
df["beds"] = df["beds"].astype(str).str.replace(" ", "")
df["beds"] = df["beds"].astype(int)

# %%
df["year"] = pd.to_datetime(df["year"], format="%Y").dt.year.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   province       744 non-null    object
#  1   hospital_type  744 non-null    object
#  2   year           744 non-null    int64
#  3   beds           744 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 23.4+ KB

# %%
# !pip install pandas-gbq

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from pandas_gbq import to_gbq

to_gbq(
    df,
    "bitirme_projesi_datalari.hastane_yatak_sayilarinin_illere_gore_dagilimi_clean_data",
    project_id="workintech-projelerim",
    if_exists="replace"
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 7530.17it/s]

# %% [markdown]
# Hekim sayısı, Hekim Başına Düşen Kişi Sayısı ve Hekim Başına Düşen Toplam Müracaat Sayısı tablosunun düzeltilmesi

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-80ce70e4-58b5-40ac-9d07-16b3ca1df9a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80ce70e4-58b5-40ac-9d07-16b3ca1df9a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("dosya2.csv", encoding="utf-8")

# %%
df.head()
# Out:
#    date physician_count  people_per_physician\n visits_per_physician
# 0  2015         141,259                     557                4 673
# 1  2016         144 827                     551                4 735
# 2  2017         149 997                     539                4 793
# 3  2018         153 128                     536                5 110
# 4  2019         160 810                     517                5 055

# %%
df.columns = ["date", "physician_count", "people_per_physician", "visits_per_physician"]

# %%
df["date"] = pd.to_datetime(df["date"], format="%Y").dt.year.astype(int)

# %%
df["physician_count"] = df["physician_count"].astype(str).str.replace(",", "").str.replace(" ", "").astype(int)

df["people_per_physician"] = df["people_per_physician"].astype(str).str.replace(",", "").str.replace(" ", "").astype(int)

df["visits_per_physician"] = df["visits_per_physician"].astype(str).str.replace(",", "").str.replace(" ", "").astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  9 non-null      int64
#  1   physician_count       9 non-null      int64
#  2   people_per_physician  9 non-null      int64
#  3   visits_per_physician  9 non-null      int64
# dtypes: int64(4)
# memory usage: 420.0 bytes

# %%
# !pip install pandas-gbq

# %%
from google.colab import auth
auth.authenticate_user()

# %%
print(df.columns)
# Out:
# Index(['date', 'physician_count', 'people_per_physician',
#        'visits_per_physician'],
#       dtype='object')

# %%
from pandas_gbq import to_gbq

to_gbq(
    df,
    "bitirme_projesi_datalari.hekim_sayilari_clean_data",
    project_id="workintech-projelerim",
    if_exists="replace"
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 883.57it/s]

# %% [markdown]
# İl Bazında Kişi Başına Gayri Safi Yurt İçi Hasıla tablosunun düzeltilmesi

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])
df.columns = df.columns.str.strip()

print(df.columns.tolist())
# Out:
#      <input type="file" id="files-a5839d27-02cd-453c-8d87-a8d4d5bc59c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5839d27-02cd-453c-8d87-a8d4d5bc59c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.rename(columns={df.columns[0]: "city"}, inplace=True)

# %%
df_long = df.melt(
    id_vars="city",
    var_name="year",
    value_name="hasila"
)

# %%
df_long["hasila"] = df_long["hasila"].astype(str).str.replace(" ", "").astype(int)

# %%
print(df.columns.tolist())
# Out:
# ['city', '2020', '2021', '2022', '2023', '2024']

# %%
df_long = df.melt(
    id_vars="city",
    var_name="year",
    value_name="hasila"
)

# %%
print(df_long.columns.tolist())
# Out:
# ['city', 'year', 'hasila']

# %%
df_long["hasila"] = (
    df_long["hasila"]
    .astype(str)
    .str.replace(" ", "", regex=False)
    .astype(int)
)

# %%
df_long["year"] = df_long["year"].astype(int)

# %%
df_long.info()
df_long.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    405 non-null    object
#  1   year    405 non-null    int64
#  2   hasila  405 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 9.6+ KB
#          city  year  hasila
# 0    İstanbul  2020   94296
# 1    Tekirdağ  2020   83932
# 2      Edirne  2020   53060
# 3  Kırklareli  2020   70329
# 4   Balıkesir  2020   53779

# %%
# !pip install pandas-gbq

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from pandas_gbq import to_gbq

to_gbq(
    df_long,
    "bitirme_projesi_datalari.gayri_safi_yurt_ici_hasila_clean_data",
    project_id="workintech-projelerim",
    if_exists="replace"
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 10538.45it/s]

# %% [markdown]
# Türkiye toplam sağlık sigortası poliçe sayısı tablosunun düzenlenmesi

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])
df.columns = df.columns.str.strip()

print(df.columns.tolist())
# Out:
#      <input type="file" id="files-d24c91eb-9111-4689-b6a8-11bcec1a70da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d24c91eb-9111-4689-b6a8-11bcec1a70da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.columns = df.columns.str.strip()

df["date"] = df["date"].astype(int)

cols = ["dual", "health", "illness"]

for col in cols:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(" ", "", regex=False)
        .str.replace(".", "", regex=False)
        .str.replace(",", "", regex=False)
        .astype(int)
    )

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     9 non-null      int64
#  1   dual     9 non-null      int64
#  2   health   9 non-null      int64
#  3   illness  9 non-null      int64
# dtypes: int64(4)
# memory usage: 420.0 bytes
#    date     dual   health  illness
# 0  2015  3073694  1068854  2744330
# 1  2016  3331681  1353860  2800330
# 2  2017  4302549  1719974  2627300
# 3  2018  4361433  1882287  2165390
# 4  2019  6007999  2894597  2447180

# %%
# !pip install pandas-gbq

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from pandas_gbq import to_gbq

to_gbq(
    df,
    "bitirme_projesi_datalari.saglik_sigortasi_police_sayisi_clean_data",
    project_id="workintech-projelerim",
    if_exists="replace"
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 15534.46it/s]

# %% [markdown]
# Yıllara Göre İl Nufüsları Tablosunun düzeltilmesi

# %%
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/1xOACw3R58DHsmUXloQ411FE1x4HjgARcgaPuhZaVmY4/export?format=csv"

df = pd.read_csv(url)

df.columns = ["city", "year", "population"]

df["year"] = df["year"].astype(int)
df["population"] = df["population"].astype(int)

df = df.dropna()

df.head()
# Out:
#     city  year  population
# 0  Adana  2020     2258718
# 1  Adana  2021     2263373
# 2  Adana  2022     2274106
# 3  Adana  2023     2270298
# 4  Adana  2024     2280484

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        486 non-null    object
#  1   year        486 non-null    int64
#  2   population  486 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 11.5+ KB
#     city  year  population
# 0  Adana  2020     2258718
# 1  Adana  2021     2263373
# 2  Adana  2022     2274106
# 3  Adana  2023     2270298
# 4  Adana  2024     2280484

# %%
# !pip install pandas-gbq

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from pandas_gbq import to_gbq

to_gbq(
    df,
    "bitirme_projesi_datalari.nufus_sayisi_clean_data",
    project_id="workintech-projelerim",
    if_exists="replace"
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 15420.24it/s]
